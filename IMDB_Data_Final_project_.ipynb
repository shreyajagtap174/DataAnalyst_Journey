# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/imdb_data.csv")

# %%
#Lets check whether the data is load or not. check first 5 rows

# %%
df.head()
# Out:
#           id    primaryTitle   originalTitle  isAdult  runtimeMinutes  \
# 0  tt0035423  Kate & Leopold  Kate & Leopold        0             118
# 1  tt0065421  The Aristocats  The AristoCats        0              78
# 2  tt0065938  Kelly's Heroes  Kelly's Heroes        0             144
# 3  tt0066026         M*A*S*H         M*A*S*H        0             116
# 4  tt0066206          Patton          Patton        0             172
#
#                        genres  averageRating  numVotes    budget       gross  \
# 0      Comedy,Fantasy,Romance            6.4     87925  48000000  76019048.0
# 1  Adventure,Animation,Comedy            7.1    111758   4000000  35459543.0
# 2        Adventure,Comedy,War            7.6     52628   4000000   5200000.0
# 3            Comedy,Drama,War            7.4     75784   3500000  81600000.0
# 4         Biography,Drama,War            7.9    106476  12000000  61749765.0
#
#         release_date              directors
# 0  December 11, 2001          James Mangold
# 1  December 11, 1970    Wolfgang Reitherman
# 2    January 1, 1970        Brian G. Hutton
# 3   January 25, 1970          Robert Altman
# 4   February 4, 1970  Franklin J. Schaffner

# %%
#basic information about dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3348 non-null   object
#  1   primaryTitle    3348 non-null   object
#  2   originalTitle   3348 non-null   object
#  3   isAdult         3348 non-null   int64
#  4   runtimeMinutes  3348 non-null   int64
#  5   genres          3348 non-null   object
#  6   averageRating   3348 non-null   float64
#  7   numVotes        3348 non-null   int64
#  8   budget          3348 non-null   int64
#  9   gross           3297 non-null   float64
#  10  release_date    3343 non-null   object
#  11  directors       3348 non-null   object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 314.0+ KB

# %% [markdown]
# - The dataset contain 3348 rows and 12 columns
#
# - There are 6 object data type . 4 integer columns, 2 float columns.
#
# - isAdult column showing int. we need to convert this columns into Yes and No format to analyse the data properly.
#
# - release_date column is an object , which should be converted to date time format or  we seperate the date, year and month for better analysis.

# %%
#lets check for the missing values.

# %%
df.isnull().sum()
# Out:
# id                 0
# primaryTitle       0
# originalTitle      0
# isAdult            0
# runtimeMinutes     0
# genres             0
# averageRating      0
# numVotes           0
# budget             0
# gross             51
# release_date       5
# directors          0
# dtype: int64

# %% [markdown]
# - gross (51 missing values )
#
# - gross represent total earning of a movies. missing values may indicate that data was unavailable or the movie is underperformed.
#
# -possible solution - 1 -missing values replace with mean or median
#
# 2 - drop rows with missing values - 51 rows will be droped from the dataset
#
# 3 - If budget is available . then we estimate the gross using a median.
#
#
# - missing release dates - incomplete record.
# - possible solution rop the rows.

# %%
#lets replace the missing values of gross with KNN imputation

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
df[['budget', 'gross']] = imputer.fit_transform(df[['budget', 'gross']])

# %%
df.isnull().sum()
# Out:
# id                0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# runtimeMinutes    0
# genres            0
# averageRating     0
# numVotes          0
# budget            0
# gross             0
# release_date      5
# directors         0
# dtype: int64

# %%
#drop release date rows

# %%
df = df.dropna(subset=['release_date'])

# %%
df.shape
# Out:
# (3343, 12)

# %% [markdown]
# - After successfully removing the null values we have clean dataset.
#
# - total 3343 rows and 12 columns.
#
# - so lets start to do EDA

# %%
df.columns
# Out:
# Index(['id', 'primaryTitle', 'originalTitle', 'isAdult', 'runtimeMinutes',
#        'genres', 'averageRating', 'numVotes', 'budget', 'gross',
#        'release_date', 'directors'],
#       dtype='object')

# %%
#lets find out  How many unique movies are in the dataset?

# %%
df['id'].nunique()
# Out:
# 3343

# %% [markdown]
# so we have 3343 unique movies. so that mean we dont have any duplicated values in the dataset.

# %%
#lets check the overall distribution of movie runtime.

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['runtimeMinutes'], bins=60, kde=True, color='royalblue')
plt.xlabel("Runtime(minutes)")
plt.ylabel("Count of the movies")
plt.title("Distribution of Movie Runtime")
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Runtime')

# %%
#as we see the distribution. it seems like normal distribution. but lets check for the outliers also

# %%
plt.figure(figsize=(8,6))
sns.boxplot(df['runtimeMinutes'])
plt.xlabel("Runtime(minutes)")
plt.title("Boxplot of Movie Runtime")
plt.savefig("Runtime.png", dpi=300)

# %%
#lets check How many movies are marked as "Adult" (isAdult=1) vs. non-adult (isAdult=0)?

# %%
df['isAdult'].unique()
# Out:
# array([0])

# %% [markdown]
# - as weseen we have only one category in adult section.
#
# - that mean all movies is only for Adult
#
# - so for better analysis we drop the adult column

# %%
df.drop(columns=['isAdult'], inplace=True)

# %%
#What are the top 10 most common movie genres?

# %%
df.head(1)
# Out:
#           id    primaryTitle   originalTitle  runtimeMinutes  \
# 0  tt0035423  Kate & Leopold  Kate & Leopold             118
#
#                    genres  averageRating  numVotes      budget       gross  \
# 0  Comedy,Fantasy,Romance            6.4     87925  48000000.0  76019048.0
#
#         release_date      directors
# 0  December 11, 2001  James Mangold

# %%
genres_list = df['genres'].str.split(",").explode()

# %%
genres_list
# Out:
# 0          Comedy
# 0         Fantasy
# 0         Romance
# 1       Adventure
# 1       Animation
#           ...
# 3346    Adventure
# 3346       Horror
# 3347       Comedy
# 3347        Crime
# 3347        Drama
# Name: genres, Length: 8948, dtype: object

# %%
genres_counts = genres_list.value_counts().head(10)

# %%
genres_counts
# Out:
# genres
# Drama        1542
# Comedy       1176
# Action       1171
# Adventure     894
# Crime         652
# Thriller      632
# Romance       441
# Horror        402
# Mystery       376
# Sci-Fi        376
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=genres_counts.index, y=genres_counts.values, palette='viridis')
plt.title("Top 10 most common genres")
plt.xlabel("Top 10 Generes")
plt.ylabel("Number of movies")
# Out:
# <ipython-input-33-4d1000c1601d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genres_counts.index, y=genres_counts.values, palette='viridis')
# Text(0, 0.5, 'Number of movies')

# %% [markdown]
# - Drama is the most dminant genre with 1542 movies
#
# -comedy and action are almost eqal ~ 1170
#
# - Adventure , crime and thriller are strong contenders -
#
# -romance , horror, mystery an si-fi are mid tier genres.

# %%
#What is the distribution of averageRating? Are ratings skewed toward high or low values?

# %%
df.columns
# Out:
# Index(['id', 'primaryTitle', 'originalTitle', 'runtimeMinutes', 'genres',
#        'averageRating', 'numVotes', 'budget', 'gross', 'release_date',
#        'directors'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.histplot(df['averageRating'], bins = 30, kde=True)
plt.xlabel("AverageRating")
plt.ylabel("Counts")
plt.title("Distribution of Average Rating")
# Out:
# Text(0.5, 1.0, 'Distribution of Average Rating')

# %%
#lets see how many movies are very low and very high rated

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x= df['averageRating'])
plt.xlabel("Average Rating")
plt.title("Boxplot of average rating")
# Out:
# Text(0.5, 1.0, 'Boxplot of average rating')

# %% [markdown]
# - Most movies are well rated
#
# - The majority of rating are above 6  to 8 indicating positive bias in user reviews.
#
# -some movies are high rated movies. looks like outliers.
#
# -there are fewer low rated movies, looks outlier, meaning people dontbother to rate them. low rated movies. - prabalely disliked by audiences.

# %%
#How many movies have received over 100,000 votes (numVotes > 100,000)?

# %%
high_vote_movies = df[df['numVotes']>100000]

# %%
high_vote_movies.shape
# Out:
# (2099, 11)

# %%
plt.figure(figsize=(12,8))
sns.histplot(df['numVotes'], bins = 80, kde= True)
plt.xlabel("Number of votes")
plt.ylabel("Counts")
plt.title("Distribution of movies votes")
# Out:
# Text(0.5, 1.0, 'Distribution of movies votes')

# %%
#7. What is the distribution of movie budgets?

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['budget'], bins = 30, kde=True)
plt.xlabel("Budget of Movies")
plt.ylabel("Count")
plt.title("Distribution of Movies Budget")
# Out:
# Text(0.5, 1.0, 'Distribution of Movies Budget')

# %% [markdown]
# - the budget distriution id right skewed
#
# - many movies had low budget movies
#
# - few movies only had high budgets

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x= df['budget'])
plt.xlabel("Budget of movies")
plt.title("Boxplot of Movies Budget")
# Out:
# Text(0.5, 1.0, 'Boxplot of Movies Budget')

# %%
#. What is the distribution of gross revenue?

# %%
df.columns
# Out:
# Index(['id', 'primaryTitle', 'originalTitle', 'runtimeMinutes', 'genres',
#        'averageRating', 'numVotes', 'budget', 'gross', 'release_date',
#        'directors'],
#       dtype='object')

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['gross'], bins = 30, kde=True)
plt.xlabel("gross revenue of Movies")
plt.ylabel("Count")
plt.title("Distribution of Movies Gross Revenue")
# Out:
# Text(0.5, 1.0, 'Distribution of Movies Gross Revenue')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x= df['gross'])
plt.xlabel("gross revenue of movies")
plt.title("Boxplot of Movies gross revenue")
# Out:
# Text(0.5, 1.0, 'Boxplot of Movies gross revenue')

# %% [markdown]
# - gross revenue distribution is right skewed
#
# - a few blockbuster movies earning massive amount
#
# - there outliers movies with extream earnings.

# %%
#What is the average budget and gross revenue of movies?

# %%
avg_budget = df['budget'].mean()

# %%
avg_gross = df['gross'].mean()

# %%
avg_budget
# Out:
# np.float64(50425817.86299731)

# %%
avg_gross
# Out:
# np.float64(167729001.37349686)

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=['avg_budget', 'avg_gross'],
            y = [avg_budget, avg_gross], palette='viridis')
plt.title("Comparision of average budget vs. gross")
# Out:
# <ipython-input-55-e3e0ed8b6028>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['avg_budget', 'avg_gross'],
# Text(0.5, 1.0, 'Comparision of average budget vs. gross')

# %% [markdown]
# - average gross exceed the average budget, indicating overall profitability

# %%
#. Is there a significant correlation between budget and gross revenue?

# %%
correlatio_matrix = df[["budget", "gross"]].corr()

# %%
correlatio_matrix
# Out:
#           budget     gross
# budget  1.000000  0.699016
# gross   0.699016  1.000000

# %%
plt.figure(figsize=(6,6))
sns.heatmap(correlatio_matrix,annot=True, cmap="coolwarm" )
plt.title("Correlation betw. budget and gross revenue")
# Out:
# Text(0.5, 1.0, 'Correlation betw. budget and gross revenue')

# %% [markdown]
# - strong positive correlation ~ 0.699 between budget and gross revenue.
#
# - this means higher budget movies tends to greater higher revenue.

# %%
# Do high-budget movies tend to have higher ratings?

# %%
df.columns
# Out:
# Index(['id', 'primaryTitle', 'originalTitle', 'runtimeMinutes', 'genres',
#        'averageRating', 'numVotes', 'budget', 'gross', 'release_date',
#        'directors'],
#       dtype='object')

# %%
correlatio_matrix = df[["budget", "averageRating"]].corr()

# %%
correlatio_matrix
# Out:
#                  budget  averageRating
# budget         1.000000      -0.079107
# averageRating -0.079107       1.000000

# %%
plt.figure(figsize=(6,6))
sns.heatmap(correlatio_matrix,annot=True, cmap="coolwarm" )
plt.title("Correlation betw. budget and average rating")
# Out:
# Text(0.5, 1.0, 'Correlation betw. budget and average rating')

# %% [markdown]
# - weak negative correlation ~ -0.079
#
# - suggest almost no relationship between budget and average rating

# %%
#Which are the top 10 highest-grossing movies?

# %%
top_grossing = df[["primaryTitle","gross"]].sort_values(by='gross', ascending= False).head(10)

# %%
top_grossing
# Out:
#                                     primaryTitle         gross
# 1762                                      Avatar  2.923706e+09
# 3055                           Avengers: Endgame  2.799439e+09
# 2514                    Avatar: The Way of Water  2.320250e+09
# 726                                      Titanic  2.264743e+09
# 2850  Star Wars: Episode VII - The Force Awakens  2.071310e+09
# 3054                      Avengers: Infinity War  2.052415e+09
# 2051                     Spider-Man: No Way Home  1.921847e+09
# 1368                              Jurassic World  1.671537e+09
# 3201                               The Lion King  1.663075e+09
# 1859                                The Avengers  1.520539e+09

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= top_grossing["gross"], y =top_grossing['primaryTitle'], palette="viridis")
plt.xlabel("Gross Revenue")
plt.ylabel("Movie Title")
plt.title("Top 10 Highest grossing movies")
# Out:
# <ipython-input-68-2c416fba6c9d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= top_grossing["gross"], y =top_grossing['primaryTitle'], palette="viridis")
# Text(0.5, 1.0, 'Top 10 Highest grossing movies')

# %%
#Which are the top 10 most profitable movies (profit = gross - budget)?

# %%
df['profit'] = df['gross'] - df['budget']

# %%
top_profitable = df.sort_values(by ='profit', ascending= False).head(10)

# %%
top_profitable
# Out:
#               id                                primaryTitle  \
# 1762   tt0499549                                      Avatar
# 3055   tt4154796                           Avengers: Endgame
# 726    tt0120338                                     Titanic
# 2514   tt1630029                    Avatar: The Way of Water
# 2850   tt2488496  Star Wars: Episode VII - The Force Awakens
# 3054   tt4154756                      Avengers: Infinity War
# 2051  tt10872600                     Spider-Man: No Way Home
# 1368   tt0369610                              Jurassic World
# 3201   tt6105098                               The Lion King
# 2427   tt1517268                                      Barbie
#
#                                    originalTitle  runtimeMinutes  \
# 1762                                      Avatar             162
# 3055                           Avengers: Endgame             181
# 726                                      Titanic             194
# 2514                    Avatar: The Way of Water             192
# 2850  Star Wars: Episode VII - The Force Awakens             138
# 3054                      Avengers: Infinity War             149
# 2051                     Spider-Man: No Way Home             148
# 1368                              Jurassic World             124
# 3201                               The Lion King             118
# 2427                                      Barbie             114
#
#                          genres  averageRating  numVotes       budget  \
# 1762   Action,Adventure,Fantasy            7.9   1364568  237000000.0
# 3055     Action,Adventure,Drama            8.4   1224453  356000000.0
# 726               Drama,Romance            7.9   1252486  200000000.0
# 2514   Action,Adventure,Fantasy            7.6    466743  350000000.0
# 2850    Action,Adventure,Sci-Fi            7.8    960165  245000000.0
# 3054    Action,Adventure,Sci-Fi            8.4   1164767  321000000.0
# 2051   Action,Adventure,Fantasy            8.2    841498  200000000.0
# 1368    Action,Adventure,Sci-Fi            6.9    668305  150000000.0
# 3201  Adventure,Animation,Drama            6.8    260956  260000000.0
# 2427   Adventure,Comedy,Fantasy            7.0    376979  100000000.0
#
#              gross       release_date                 directors        profit
# 1762  2.923706e+09  December 10, 2009             James Cameron  2.686706e+09
# 3055  2.799439e+09     April 18, 2019  Anthony Russo, Joe Russo  2.443439e+09
# 726   2.264743e+09   November 1, 1997             James Cameron  2.064743e+09
# 2514  2.320250e+09   December 6, 2022             James Cameron  1.970250e+09
# 2850  2.071310e+09  December 14, 2015               J.J. Abrams  1.826310e+09
# 3054  2.052415e+09     April 23, 2018  Anthony Russo, Joe Russo  1.731415e+09
# 2051  1.921847e+09  December 13, 2021                 Jon Watts  1.721847e+09
# 1368  1.671537e+09       May 29, 2015           Colin Trevorrow  1.521537e+09
# 3201  1.663075e+09       July 9, 2019               Jon Favreau  1.403075e+09
# 2427  1.441660e+09       July 9, 2023              Greta Gerwig  1.341660e+09

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= top_profitable["profit"], y =top_profitable['primaryTitle'], palette="viridis")
plt.xlabel("profit")
plt.ylabel("Movie Title")
plt.title("Top 10 Highest profitable movies")
# Out:
# <ipython-input-73-43c39d51a041>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= top_profitable["profit"], y =top_profitable['primaryTitle'], palette="viridis")
# Text(0.5, 1.0, 'Top 10 Highest profitable movies')

# %%
#14. Are movies with a higher number of votes (numVotes) more profitable?

# %%
correlatio_matrix = df[["numVotes", "profit"]].corr()

# %%
correlatio_matrix
# Out:
#           numVotes    profit
# numVotes  1.000000  0.528258
# profit    0.528258  1.000000

# %%
plt.figure(figsize=(6,6))
sns.heatmap(correlatio_matrix,annot=True, cmap="coolwarm" )
plt.title("Correlation betw. numVotes and Profit")
# Out:
# Text(0.5, 1.0, 'Correlation betw. numVotes and Profit')

# %% [markdown]
# - The correlation bet. number of votes and profit is 0.53 which indicates a moderate positive correlation.

# %%
# 15 Which genre has the highest number of movies? (same as 4rth qu )

# %% [markdown]
# - The genre with the highest number of movies is Drama, with 1542 movies.

# %%
#16 What are the average budget and gross revenue per genre?

# %%
df.head(1)
# Out:
#           id    primaryTitle   originalTitle  runtimeMinutes  \
# 0  tt0035423  Kate & Leopold  Kate & Leopold             118
#
#                    genres  averageRating  numVotes      budget       gross  \
# 0  Comedy,Fantasy,Romance            6.4     87925  48000000.0  76019048.0
#
#         release_date      directors      profit
# 0  December 11, 2001  James Mangold  28019048.0

# %%
new_df = df.copy()

# %%
new_df['genres'] = new_df['genres'].str.split(",")

# %%
new_df = new_df.explode("genres")

# %%
new_df
# Out:
#              id                          primaryTitle  \
# 0     tt0035423                        Kate & Leopold
# 0     tt0035423                        Kate & Leopold
# 0     tt0035423                        Kate & Leopold
# 1     tt0065421                        The Aristocats
# 1     tt0065421                        The Aristocats
# ...         ...                                   ...
# 3346  tt9844522  Escape Room: Tournament of Champions
# 3346  tt9844522  Escape Room: Tournament of Champions
# 3347  tt9893250                          I Care a Lot
# 3347  tt9893250                          I Care a Lot
# 3347  tt9893250                          I Care a Lot
#
#                              originalTitle  runtimeMinutes     genres  \
# 0                           Kate & Leopold             118     Comedy
# 0                           Kate & Leopold             118    Fantasy
# 0                           Kate & Leopold             118    Romance
# 1                           The AristoCats              78  Adventure
# 1                           The AristoCats              78  Animation
# ...                                    ...             ...        ...
# 3346  Escape Room: Tournament of Champions              88  Adventure
# 3346  Escape Room: Tournament of Champions              88     Horror
# 3347                          I Care a Lot             118     Comedy
# 3347                          I Care a Lot             118      Crime
# 3347                          I Care a Lot             118      Drama
#
#       averageRating  numVotes      budget       gross        release_date  \
# 0               6.4     87925  48000000.0  76019048.0   December 11, 2001
# 0               6.4     87925  48000000.0  76019048.0   December 11, 2001
# 0               6.4     87925  48000000.0  76019048.0   December 11, 2001
# 1               7.1    111758   4000000.0  35459543.0   December 11, 1970
# 1               7.1    111758   4000000.0  35459543.0   December 11, 1970
# ...             ...       ...         ...         ...                 ...
# 3346            5.7     56955  15000000.0  65774490.0        July 1, 2021
# 3346            5.7     56955  15000000.0  65774490.0        July 1, 2021
# 3347            6.4    141433  14000000.0   1351662.0  September 12, 2020
# 3347            6.4    141433  14000000.0   1351662.0  September 12, 2020
# 3347            6.4    141433  14000000.0   1351662.0  September 12, 2020
#
#                 directors      profit
# 0           James Mangold  28019048.0
# 0           James Mangold  28019048.0
# 0           James Mangold  28019048.0
# 1     Wolfgang Reitherman  31459543.0
# 1     Wolfgang Reitherman  31459543.0
# ...                   ...         ...
# 3346         Adam Robitel  50774490.0
# 3346         Adam Robitel  50774490.0
# 3347           J Blakeson -12648338.0
# 3347           J Blakeson -12648338.0
# 3347           J Blakeson -12648338.0
#
# [8948 rows x 12 columns]

# %%
avg_rev_gross = new_df.groupby("genres")[["budget", "gross"]].mean().sort_values(by="gross", ascending= False)

# %%
avg_rev_gross = avg_rev_gross.head(10)

# %%
avg_rev_gross
# Out:
#                  budget         gross
# genres
# Animation  9.261869e+07  3.718782e+08
# Adventure  9.342321e+07  3.240299e+08
# Family     7.331553e+07  2.584685e+08
# Sci-Fi     7.823706e+07  2.486523e+08
# Fantasy    7.262359e+07  2.438574e+08
# Action     7.749185e+07  2.354541e+08
# Comedy     4.518031e+07  1.572124e+08
# Musical    3.950357e+07  1.494457e+08
# Thriller   4.132095e+07  1.345612e+08
# Western    3.649444e+07  1.213595e+08

# %%
plt.figure(figsize=(14,6))
sns.barplot(data = avg_rev_gross , x = "genres", y='budget', color = 'blue', label = "Average budget")
sns.barplot(data = avg_rev_gross , x = "genres", y='gross', color = 'skyblue', alpha = 0.7, label ="Average gross revenue")
plt.ylabel("Average Revenue")
plt.title("Average budget & gross per genre")
# Out:
# Text(0.5, 1.0, 'Average budget & gross per genre')

# %%
#Which genre has the highest average rating?

# %%
genre_avg_rating = new_df.groupby("genres")["averageRating"].mean().reset_index()

# %%
genre_avg_rating
# Out:
#          genres  averageRating
# 0        Action       6.559180
# 1     Adventure       6.650112
# 2     Animation       7.107576
# 3     Biography       7.301299
# 4        Comedy       6.580357
# 5         Crime       6.846012
# 6   Documentary       7.053846
# 7         Drama       7.054086
# 8        Family       6.566480
# 9       Fantasy       6.485928
# 10      History       7.233333
# 11       Horror       6.290299
# 12        Music       6.873973
# 13      Musical       7.075000
# 14      Mystery       6.684840
# 15         News       7.400000
# 16      Romance       6.693878
# 17       Sci-Fi       6.527394
# 18        Sport       6.873913
# 19     Thriller       6.659019
# 20          War       7.438776
# 21      Western       7.216667

# %%
top_genre_rating = genre_avg_rating.sort_values(by="averageRating", ascending= False).head(5)

# %%
top_genre_rating
# Out:
#        genres  averageRating
# 20        War       7.438776
# 15       News       7.400000
# 3   Biography       7.301299
# 10    History       7.233333
# 21    Western       7.216667

# %%
plt.figure(figsize=(6,4))
sns.barplot(data = top_genre_rating, x= "genres", y = "averageRating", palette="viridis")
plt.title("Average Rating per genres")
# Out:
# <ipython-input-94-2dd911884f06>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_genre_rating, x= "genres", y = "averageRating", palette="viridis")
# Text(0.5, 1.0, 'Average Rating per genres')

# %% [markdown]
# - War movies have the highest average rating ~ 7.44 , indicating that audiences generally rate them highly , possibly due to strong storytelling and emotional depth

# %%
# Are there genres that tend to have longer runtimes?

# %%
new_df.head(1)
# Out:
#           id    primaryTitle   originalTitle  runtimeMinutes  genres  \
# 0  tt0035423  Kate & Leopold  Kate & Leopold             118  Comedy
#
#    averageRating  numVotes      budget       gross       release_date  \
# 0            6.4     87925  48000000.0  76019048.0  December 11, 2001
#
#        directors      profit
# 0  James Mangold  28019048.0

# %%
genre_runtime = new_df.groupby("genres")["runtimeMinutes"].mean().reset_index()

# %%
genre_runtime
# Out:
#          genres  runtimeMinutes
# 0        Action      115.755764
# 1     Adventure      114.086130
# 2     Animation       94.621212
# 3     Biography      126.324675
# 4        Comedy      103.983844
# 5         Crime      114.711656
# 6   Documentary      101.307692
# 7         Drama      119.234112
# 8        Family      105.960894
# 9       Fantasy      114.086826
# 10      History      136.494624
# 11       Horror      102.517413
# 12        Music      113.643836
# 13      Musical      123.357143
# 14      Mystery      111.335106
# 15         News       96.000000
# 16      Romance      113.108844
# 17       Sci-Fi      114.590426
# 18        Sport      114.608696
# 19     Thriller      111.405063
# 20          War      129.938776
# 21      Western      123.500000

# %%
top_genre_runtime = genre_runtime.sort_values(by ="runtimeMinutes", ascending= False).head(5)

# %%
top_genre_runtime
# Out:
#        genres  runtimeMinutes
# 10    History      136.494624
# 20        War      129.938776
# 3   Biography      126.324675
# 21    Western      123.500000
# 13    Musical      123.357143

# %%
plt.figure(figsize=(6,4))
sns.barplot(data = top_genre_runtime, x= "genres", y = "runtimeMinutes", palette="viridis")
plt.title("Average runtimeMinutes per genres")
# Out:
# <ipython-input-101-c15036c1e99c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_genre_runtime, x= "genres", y = "runtimeMinutes", palette="viridis")
# Text(0.5, 1.0, 'Average runtimeMinutes per genres')

# %% [markdown]
# - History movies have highest average runtime ~ 136 minutes, likely due to their detailed storytelling.
#
# - War films ~ 129 minutes also tend to be long.

# %%
#Are movies with a higher number of votes (numVotes) more profitable?

# %%
#What is the correlation between numVotes and averageRating?

# %%
correlatio_matrix = df[["numVotes","averageRating"]].corr()

# %%
correlatio_matrix
# Out:
#                numVotes  averageRating
# numVotes       1.000000       0.484569
# averageRating  0.484569       1.000000

# %%
#scatter plot with regression line

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x="numVotes", y="averageRating")
plt.xlabel("Number of votes")
plt.ylabel("Average Rating")
plt.title("Correlation between number of votes and average rating")
# Out:
# Text(0.5, 1.0, 'Correlation between number of votes and average rating')

# %%
sns.heatmap(correlatio_matrix, annot= True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# - The correlation of 0.48 suggest that moderate positive correlation,  that mean the movies with higher votes tend to have higher rating.
#
# - movies generally get good rating there are more.

# %%
# What are the top 10 highest-rated movies?

# %%
top_rated_movies = df.sort_values(by="averageRating", ascending= False).head(10)

# %%
top_rated_movies
# Out:
#              id                                       primaryTitle  \
# 529   tt0111161                           The Shawshank Redemption
# 17    tt0068646                                      The Godfather
# 488   tt0108052                                   Schindler's List
# 1691  tt0468569                                    The Dark Knight
# 908   tt0167260      The Lord of the Rings: The Return of the King
# 38    tt0071562                              The Godfather Part II
# 523   tt0110912                                       Pulp Fiction
# 759   tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 508   tt0109830                                       Forrest Gump
# 2323  tt1375666                                          Inception
#
#                                           originalTitle  runtimeMinutes  \
# 529                            The Shawshank Redemption             142
# 17                                        The Godfather             175
# 488                                    Schindler's List             195
# 1691                                    The Dark Knight             152
# 908       The Lord of the Rings: The Return of the King             201
# 38                                The Godfather Part II             202
# 523                                        Pulp Fiction             154
# 759   The Lord of the Rings: The Fellowship of the Ring             178
# 508                                        Forrest Gump             142
# 2323                                          Inception             148
#
#                        genres  averageRating  numVotes       budget  \
# 529                     Drama            9.3   2817283   25000000.0
# 17                Crime,Drama            9.2   1963432    6000000.0
# 488   Biography,Drama,History            9.0   1416181   22000000.0
# 1691       Action,Crime,Drama            9.0   2798830  185000000.0
# 908    Action,Adventure,Drama            9.0   1929275   94000000.0
# 38                Crime,Drama            9.0   1333027   13000000.0
# 523               Crime,Drama            8.9   2160463    8000000.0
# 759    Action,Adventure,Drama            8.8   1956438   93000000.0
# 508             Drama,Romance            8.8   2194012   55000000.0
# 2323  Action,Adventure,Sci-Fi            8.8   2484142  160000000.0
#
#              gross        release_date             directors        profit
# 529   2.888472e+07  September 10, 1994        Frank Darabont  3.884716e+06
# 17    2.503418e+08      March 14, 1972  Francis Ford Coppola  2.443418e+08
# 488   3.221612e+08   November 30, 1993      Steven Spielberg  3.001612e+08
# 1691  1.007337e+09       July 14, 2008     Christopher Nolan  8.223369e+08
# 908   1.155595e+09    December 1, 2003         Peter Jackson  1.061595e+09
# 38    4.796192e+07   December 12, 1974  Francis Ford Coppola  3.496192e+07
# 523   2.139288e+08        May 21, 1994     Quentin Tarantino  2.059288e+08
# 759   8.985237e+08   December 10, 2001         Peter Jackson  8.055237e+08
# 508   6.782265e+08       June 23, 1994       Robert Zemeckis  6.232265e+08
# 2323  8.390306e+08        July 8, 2010     Christopher Nolan  6.790306e+08

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = top_rated_movies , x= "averageRating", y="originalTitle", palette= "rocket")
plt.xlabel("Average Rating")
plt.ylabel("Movie Title")
plt.title("Top 10 average Rating Movies")
plt.savefig("Top_10_highest_movies.jpeg",dpi = 300)
# Out:
# <ipython-input-112-dccf03753451>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_rated_movies , x= "averageRating", y="originalTitle", palette= "rocket")

# %%
lowest_rated_movies = df.sort_values(by="averageRating", ascending= False).tail(10)

# %%
lowest_rated_movies
# Out:
#              id                    primaryTitle  \
# 3180  tt5697572                            Cats
# 1685  tt0466342                      Date Movie
# 1175  tt0299930                           Gigli
# 2060  tt1098327            Dragonball Evolution
# 944   tt0185183               Battlefield Earth
# 1801  tt0799949                      Epic Movie
# 1333  tt0362165                 Son of the Mask
# 2180  tt1213644                  Disaster Movie
# 2562  tt1702443  Justin Bieber: Never Say Never
# 3197  tt5988370                            Reis
#
#                        originalTitle  runtimeMinutes  \
# 3180                            Cats             110
# 1685                      Date Movie              83
# 1175                           Gigli             121
# 2060            Dragonball Evolution              85
# 944                Battlefield Earth             117
# 1801                      Epic Movie              86
# 1333                 Son of the Mask              94
# 2180                  Disaster Movie              87
# 2562  Justin Bieber: Never Say Never             105
# 3197                            Reis             108
#
#                         genres  averageRating  numVotes      budget  \
# 3180       Comedy,Drama,Family            2.8     54638  95000000.0
# 1685            Comedy,Romance            2.8     61566  20000000.0
# 1175      Comedy,Crime,Romance            2.6     50335  54000000.0
# 2060  Action,Adventure,Fantasy            2.5     78236  30000000.0
# 944    Action,Adventure,Sci-Fi            2.5     82348  73000000.0
# 1801  Adventure,Comedy,Fantasy            2.4    108506  20000000.0
# 1333     Comedy,Family,Fantasy            2.3     58583  84000000.0
# 2180             Comedy,Sci-Fi            1.9     93840  20000000.0
# 2562         Documentary,Music            1.7     76394  13000000.0
# 3197           Biography,Drama            1.0     73940   8000000.0
#
#            gross       release_date                       directors  \
# 3180  75558925.0  December 16, 2019                      Tom Hooper
# 1685  85749034.0  February 17, 2006  Aaron Seltzer, Jason Friedberg
# 1175   7266209.0      July 27, 2003                    Martin Brest
# 2060  55720772.0     March 10, 2009                      James Wong
# 944   29725663.0       May 10, 2000                 Roger Christian
# 1801  87238158.0    January 1, 2007  Jason Friedberg, Aaron Seltzer
# 1333  59981548.0  February 11, 2005               Lawrence Guterman
# 2180  34816824.0    August 29, 2008  Jason Friedberg, Aaron Seltzer
# 2562  99036827.0   February 9, 2011                      Jon M. Chu
# 3197    538551.0      March 2, 2017                 Hüdaverdi Yavuz
#
#           profit
# 3180 -19441075.0
# 1685  65749034.0
# 1175 -46733791.0
# 2060  25720772.0
# 944  -43274337.0
# 1801  67238158.0
# 1333 -24018452.0
# 2180  14816824.0
# 2562  86036827.0
# 3197  -7461449.0

# %%
lowest_rated_movies = df.sort_values(by="averageRating").head(10)

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = lowest_rated_movies, x= "averageRating", y="originalTitle", palette= "rocket")
plt.xlabel("Average Rating")
plt.ylabel("Movie Title")
plt.title("Lowest average Rating Movies")
# Out:
# <ipython-input-116-d749f4c4415f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = lowest_rated_movies, x= "averageRating", y="originalTitle", palette= "rocket")
# Text(0.5, 1.0, 'Lowest average Rating Movies')

# %%
#Do longer movies tend to have higher ratings?

# %%
correlatio_matrix = df[['runtimeMinutes', 'averageRating']].corr()

# %%
correlatio_matrix
# Out:
#                 runtimeMinutes  averageRating
# runtimeMinutes         1.00000        0.36004
# averageRating          0.36004        1.00000

# %%
sns.heatmap(correlatio_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# - The correaltion coeff. is 0.36 suggest a moderate positive relationship between runtime and rating.
#
# - This means longer movies tend to have higher rating, but the effect is not very strong.

# %%
#25  Which directors have directed the most movies?

# %%
top_director = df['directors'].value_counts()

# %%
top_5_director = top_director.head(5)

# %%
top_5_director
# Out:
# directors
# Steven Spielberg    30
# Ridley Scott        23
# Martin Scorsese     21
# Clint Eastwood      20
# Ron Howard          19
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=top_5_director.values, y=top_5_director.index, palette="mako")
plt.xlabel("Number of movies")
plt.ylabel("Directors Name")
plt.title("Top 5 directors with most movies")
# Out:
# <ipython-input-127-d975bf7cfb22>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_5_director.values, y=top_5_director.index, palette="mako")
# Text(0.5, 1.0, 'Top 5 directors with most movies')

# %%
#Which directors have the highest-grossing movies?

# %%
top_grossing_director = df.groupby("directors")["gross"].sum().sort_values(ascending= False).head(5)

# %%
top_grossing_director
# Out:
# directors
# Steven Spielberg    1.057750e+10
# James Cameron       8.707895e+09
# Michael Bay         6.878564e+09
# Peter Jackson       6.624292e+09
# David Yates         6.425191e+09
# Name: gross, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=top_grossing_director.values, y=top_grossing_director.index, palette="mako")
plt.xlabel("Total gross revenue")
plt.ylabel("Directors Name")
plt.title("Top 5 directors with most gross revenue movies")
# Out:
# <ipython-input-141-87c33bfb9922>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_grossing_director.values, y=top_grossing_director.index, palette="mako")
# Text(0.5, 1.0, 'Top 5 directors with most gross revenue movies')

# %%
#Which directors have the highest-rated movies on average?

# %%
top_rated_director = df.groupby("directors")["averageRating"].mean().sort_values(ascending=False).head(5)

# %%
top_rated_director
# Out:
# directors
# Kemp Powers, Joaquim Dos Santos, Justin K. Thompson    8.7
# Roberto Benigni                                        8.6
# Tony Kaye                                              8.5
# Isao Takahata                                          8.5
# Roger Allers, Rob Minkoff                              8.5
# Name: averageRating, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=top_rated_director.values, y=top_rated_director.index, palette="mako")
plt.xlabel("Average Rating")
plt.ylabel("Directors Name")
plt.title("Top 5 directors with most rated movies")
# Out:
# <ipython-input-149-760bc65819bb>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_rated_director.values, y=top_rated_director.index, palette="mako")
# Text(0.5, 1.0, 'Top 5 directors with most rated movies')

# %%
#Are there directors known for making high-budget movies?

# %%
top_budget_director = df.groupby("directors")["budget"].mean().sort_values(ascending=False).head(5)

# %%
top_budget_director
# Out:
# directors
# Louis Leterrier, Justin Lin        340000000.0
# Nathan Greno, Byron Howard         260000000.0
# Espen Sandberg, Joachim Rønning    230000000.0
# Anthony Russo, Joe Russo           225250000.0
# Joe Russo, Anthony Russo           225000000.0
# Name: budget, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=top_budget_director.values, y=top_budget_director.index, palette="mako")
plt.xlabel("Average Budget")
plt.ylabel("Directors Name")
plt.title("Top 5 directors with hugh budget movies")
# Out:
# <ipython-input-153-bbd5c8042b9a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_budget_director.values, y=top_budget_director.index, palette="mako")
# Text(0.5, 1.0, 'Top 5 directors with hugh budget movies')

# %%
#Are there any extreme outliers in budget, gross revenue, or rating?

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,1)
sns.boxplot(y=df['budget'])
plt.title("Budget Outlier")


plt.subplot(1,3,2)
sns.boxplot(y=df['gross'])
plt.title("Gross Outlier")


plt.subplot(1,3,3)
sns.boxplot(y=df['averageRating'])
plt.title("Average Rating Outlier")
# Out:
# Text(0.5, 1.0, 'Average Rating Outlier')

# %%
#Do outliers in budget affect movie performance?

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['budget'], y=df['gross'], alpha =0.6)
plt.xlabel("Budget of movies")
plt.ylabel("Gross Revenue")
plt.title("Do outliers in budget affect movie performance?")
#plt.xscale("log")
#plt.yscale("log")
# Out:
# Text(0.5, 1.0, 'Do outliers in budget affect movie performance?')
