# %% [markdown]
# # 1 - Define the problem / Questions
#
# # 2. Data Collections -
#
# # 3 - Data Cleaning  -
# - Handle missing values
#
# - Identify and remove duplicates
#
# - handle outliers
#
# - Transform the data into suitable format
#
# # 4- EDA - Exploratory Data Analysis.
#
# # 5- Data Visualization -
#
# # 6 - Analyze the insights & Report

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
#initial data inspection

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#As we seen , the data contain some missing values.
#so lets check the exact number

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# #insights
#
# - age - 177 missing values - should be imputed based on pclass or sex - replace by mean or median
#
# - embarked - 2 missing values - can be filled with mode
#
# - deck - massive missing values - better to drop this column

# %% [markdown]
# # .fillna()
#
# # .dropna - .dop()

# %%
#fill with median age based on pclass & sex

# %%
titanic['age'] =titanic.groupby(['pclass', 'sex'])['age'].transform(lambda x : x.fillna(x.median()))

# %%
titanic['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
#replace embark with mode

# %%
titanic['embarked'].mode()[0]
# Out:
# 'S'

# %%
titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace = True)
#inplace = True is for permenent changes
# Out:
# <ipython-input-213-ad8b6e37aa77>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace = True)

# %%
titanic['embarked'].isnull().sum()
# Out:
# np.int64(0)

# %%
titanic.drop(columns=['deck'], inplace= True)

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
titanic.drop(columns=['who', 'embark_town', 'alive', 'adult_male'] , inplace= True)

# %%
titanic.isnull().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# class       0
# alone       0
# dtype: int64

# %%
titanic.shape
# Out:
# (891, 10)

# %% [markdown]
# After dropping unwanted columns the titanic dataset now has 891 rows describe the 891 passenger details and 10 columns which shows the passenger features.

# %%
#lets check for statistical summery of the data -

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  891.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.112424    0.523008    0.381594
# std       0.486592    0.836071   NaN   13.304424    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   21.500000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   26.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   36.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class alone
# count   891.000000      891    891   891
# unique         NaN        3      3     2
# top            NaN        S  Third  True
# freq           NaN      646    491   537
# mean     32.204208      NaN    NaN   NaN
# std      49.693429      NaN    NaN   NaN
# min       0.000000      NaN    NaN   NaN
# 25%       7.910400      NaN    NaN   NaN
# 50%      14.454200      NaN    NaN   NaN
# 75%      31.000000      NaN    NaN   NaN
# max     512.329200      NaN    NaN   NaN

# %% [markdown]
#  - survival rate only 38% while 62% did not survived
#
# - half of the passenger were in third class
#
# - most passenger were young adult - median age = 26 year
#
# - must be outlier in age shown 80 year old also
#
# - median fare 14.45 but max was 512.33 - it also may contain outliers
#
# -most passenger travel alone
#
# - most passenger embarked from 'S'
#
# - most passenger class is Third class

# %%
titanic.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic.duplicated().sum()
# Out:
# np.int64(118)

# %%
titanic.drop_duplicates(inplace= True)

# %%
titanic.duplicated().sum()
# Out:
# np.int64(0)

# %%
titanic.shape
# Out:
# (773, 10)

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  alone
# 0         0       3  male  22.0      1      0  7.25        S  Third  False

# %% [markdown]
# # EDA

# %%
#1 - What is the overall distribution of passengers across different classes (Pclass)?

# %%
titanic['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
pclass_count = titanic['pclass'].value_counts().sort_index()

# %%
pclass_count
# Out:
# pclass
# 1    209
# 2    164
# 3    400
# Name: count, dtype: int64

# %%
pclass_count.index
# Out:
# Index([1, 2, 3], dtype='int64', name='pclass')

# %%
pclass_count.values
# Out:
# array([209, 164, 400])

# %%
plt.figure(figsize= (8,5))
sns.barplot(x = pclass_count.index, y = pclass_count.values ,
            palette = 'pastel')
plt.xlabel("passenger class (pclass)")
plt.ylabel("number of passenger")
plt.title("Distribution of passenger accross different Pclass")
# Out:
# <ipython-input-234-2890497b755a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = pclass_count.index, y = pclass_count.values ,
# Text(0.5, 1.0, 'Distribution of passenger accross different Pclass')

# %% [markdown]
# Insights from pclass distribution
#
# - Majority of the passenger traveled in pclass3, indicating it was the most affordable and popular
#
# - Pclass 1 had the least number of passenger , suggesting that fewer people could afford luxury travel
#
# - pclass2 - had moderate number of passenger showing a middle class passenger presence on the titanic.

# %%
#2 - How is the age of passengers distributed?

# %%
plt.figure(figsize=(10,6))
sns.histplot(data = titanic , x = 'age' , bins = 30,
             kde= True, color ='skyblue')
plt.xlabel("Age of passenger")
plt.ylabel("Frequency of passenger")
plt.title("Distribution of Passenger Ages on Titanic ")
# Out:
# Text(0.5, 1.0, 'Distribution of Passenger Ages on Titanic ')

# %% [markdown]
# Insights from age distribution
#
# - The peak age group is 20-30 year . indicating many young adults traveled.
#
# - there are fewer childresn (age < 10) and elderly (age > 60)  on board
#
# - the age distributioin has a long tail on the right, indicating some passengers were much older (May be outlier) , not supposed to be board.

# %%
#3-What is the distribution of passengers based on Sex?

# %%
titanic['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
gender_count = titanic['sex'].value_counts()

# %%
gender_count
# Out:
# sex
# male      482
# female    291
# Name: count, dtype: int64

# %%
gender_count.index
# Out:
# Index(['male', 'female'], dtype='object', name='sex')

# %%
gender_count.values
# Out:
# array([482, 291])

# %%
plt.figure(figsize=(6,5))
sns.barplot(x = gender_count.index, y = gender_count.values ,
            palette= 'viridis' )
plt.xlabel("Gender of passenger")
plt.ylabel("Number of passenger")
plt.title("Distribution of Passenger based on gender")
# Out:
# <ipython-input-243-f7ecc667f25b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = gender_count.index, y = gender_count.values ,
# Text(0.5, 1.0, 'Distribution of Passenger based on gender')

# %% [markdown]
# Insights from Gender Distribution
#
# - The dataset shows more Male Passenger than Females
#
# - Since the titanic was a mix emigrants , workers, healthly workers, men might have travled more for work and opportunity.

# %%
#4 How many passengers embarked from each port (Embarked)?

# %%
titanic['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
# S - Southampton , C - Cherbourg , Q - Queenstown

# %%
embarked_count = titanic['embarked'].value_counts()

# %%
embarked_count
# Out:
# embarked
# S    562
# C    153
# Q     58
# Name: count, dtype: int64

# %%
plt.figure(figsize= (6,5))
sns.barplot(x=embarked_count.index, y =embarked_count.values,
            palette= 'rocket')
plt.xlabel("Port of Embarkation")
plt.ylabel("Number of passenger")
plt.title("Number of passenger embarked from each port")
# Out:
# <ipython-input-249-221eba30399c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=embarked_count.index, y =embarked_count.values,
# Text(0.5, 1.0, 'Number of passenger embarked from each port')

# %% [markdown]
# Insights from Embarked Distribution
#
# - Manjority of passenger embarked from S - Southampton
#
# - Moderate passenger embarked from C - Cherbourg
#
# - Q - Queenstown had least number of passenger

# %%
# What is the survival rate overall, and how does it vary by Pclass?

# %%
overall_survival_rate = titanic['survived'].mean()*100

# %%
overall_survival_rate
# Out:
# np.float64(41.52652005174644)

# %%
survival_by_pclass = titanic.groupby('pclass')['survived'].mean()*100

# %%
survival_by_pclass
# Out:
# pclass
# 1    64.114833
# 2    50.609756
# 3    26.000000
# Name: survived, dtype: float64

# %%
survival_by_pclass.index
# Out:
# Index([1, 2, 3], dtype='int64', name='pclass')

# %%
survival_by_pclass.values
# Out:
# array([64.11483254, 50.6097561 , 26.        ])

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=survival_by_pclass.index , y = survival_by_pclass.values,
            palette= 'Set1')
plt.xlabel("Passenger class")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Pclass")
# Out:
# <ipython-input-257-b16b343fb9f4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_by_pclass.index , y = survival_by_pclass.values,
# Text(0.5, 1.0, 'Survival Rate by Pclass')

# %% [markdown]
# Insighta on Surviaval rate by Pclass
#
# - Only 41% of passenger survived, indicating a high fatality rate
#
# - 1st class had highest survival rate ~ 64% ,passenger had better access to lifeboats and safety
#
# -Moderate survival rate in 2nd class ~50% , some middle class passengers survived byt not as many as pclass1
#
# -lowest survival rate in 3rd class - 26% , passenger due to fewer safety resourses.

# %%
#What is the survival rate for males vs. females?

# %%
survival_by_gender = titanic.groupby('sex')['survived'].mean()*100

# %%
survival_by_gender
# Out:
# sex
# female    73.883162
# male      21.991701
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(6,5))
sns.barplot(x = survival_by_gender.index, y =survival_by_gender.values, palette='Set1' )
plt.xlabel("Genger of Passenger")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Gender")
# Out:
# <ipython-input-261-723dc8254068>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = survival_by_gender.index, y =survival_by_gender.values, palette='Set1' )
# Text(0.5, 1.0, 'Survival Rate by Gender')

# %% [markdown]
# Insights on Survival Rate By Gender
#
# - Female had a much higher survival rate (~74%)
# - Women were prioritized during evacuation
# - Many first class & second class womens had a better access to lifeboats
#
# -Males had very low survival rate (~21%%)
# - Many men did not get lifeboats deu to evacuatioin policy.
# -

# %%
survival_by_embarked = titanic.groupby("embarked")["survived"].mean() * 100

# %%
survival_by_embarked
# Out:
# embarked
# C    58.823529
# Q    34.482759
# S    37.544484
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x=survival_by_embarked.index, y=survival_by_embarked.values, palette="pastel")

plt.xlabel("Port of Embarkation")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Embarkation Point")
# Out:
# <ipython-input-264-3306ee99ea82>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_by_embarked.index, y=survival_by_embarked.values, palette="pastel")
# Text(0.5, 1.0, 'Survival Rate by Embarkation Point')

# %% [markdown]
# Passengers from C (Cherbourg) had the highest survival rate (~58.8%)
#
# -Many first-class passengers boarded from Cherbourg, leading to a higher survival rate.
#
# -Southampton had the highest number of third-class passengers, which reduced survival chances.
#
# -Most passengers from Queenstown were in third class, which had the worst survival rate.

# %%
#8 How does the survival rate vary across different ticket classes (Pclass)?

# %%
survival_by_pclass = titanic.groupby("pclass")["survived"].mean() * 100

# %%
survival_by_pclass
# Out:
# pclass
# 1    64.114833
# 2    50.609756
# 3    26.000000
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x=survival_by_pclass.index, y=survival_by_pclass.values, palette="pastel")

plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Passenger Class")
# Out:
# <ipython-input-268-6d4d2056ae8f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_by_pclass.index, y=survival_by_pclass.values, palette="pastel")
# Text(0.5, 1.0, 'Survival Rate by Passenger Class')

# %% [markdown]
# First-Class (Pclass = 1) had the highest survival rate (~64.1%)
#
# First-class passengers were given priority in lifeboats.
# Many wealthier individuals had cabins near the deck, making evacuation easier.
# Second-Class (Pclass = 2) had a moderate survival rate (~50.6%)
#
# These passengers had a fair chance of survival but were not prioritized like first-class.
# Third-Class (Pclass = 3) had the lowest survival rate (~26.0%)
#
# Many third-class passengers were in the lower decks, making escape difficult.
# Limited access to lifeboats contributed to a high fatality rate.

# %%
#9  Is there any relationship between the number of siblings/spouses aboard (SibSp) and survival?

# %%
survival_by_sibsp = titanic.groupby("sibsp")["survived"].mean() * 100

# %%
survival_by_sibsp
# Out:
# sibsp
# 0    38.658777
# 1    53.000000
# 2    44.444444
# 3    28.571429
# 4    16.666667
# 5     0.000000
# 8     0.000000
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=survival_by_sibsp.index, y=survival_by_sibsp.values, palette="pastel")

plt.xlabel("Number of siblings/sposes Aboard")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Sibsp")
# Out:
# <ipython-input-272-4f3655e02c5a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_by_sibsp.index, y=survival_by_sibsp.values, palette="pastel")
# Text(0.5, 1.0, 'Survival Rate by Sibsp')

# %% [markdown]
# Best survival rate: Small families (1–2 SibSp).
#
# Worst survival rate: Large families (3+ SibSp).
#
# No survivors: Passengers with 5+ SibSp.

# %%
#  How does the number of parents/children aboard (Parch) affect survival?

# %%
survival_by_parch = titanic.groupby("parch")["survived"].mean() * 100

# %%
survival_by_parch
# Out:
# parch
# 0    37.609842
# 1    55.263158
# 2    53.333333
# 3    60.000000
# 4     0.000000
# 5    20.000000
# 6     0.000000
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=survival_by_parch.index, y=survival_by_parch.values, palette="pastel")

plt.xlabel("Number of Parents/children Aboard")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate by Parch")
# Out:
# <ipython-input-276-22c25f2417f6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_by_parch.index, y=survival_by_parch.values, palette="pastel")
# Text(0.5, 1.0, 'Survival Rate by Parch')

# %% [markdown]
# - Passengers with 1–3 Parents/Children Had Higher Survival Rates (~53–60%)
#
# Families with small children or parents may have received priority during evacuation.
# They likely got more assistance and access to lifeboats.
#
# Passengers Traveling Alone (Parch = 0) Had Lower Survival (~37.6%)
#
# Traveling alone reduced chances of getting help.
# They were less likely to be prioritized.
#
# - Passengers with 4+ Parch Had the Worst Survival Rates (0-20%)
#
# Large families likely struggled to stay together.
# Difficulty in securing spots for all members in lifeboats.
# Parch = 4 & 6 had 0% survival, indicating entire families perished.

# %%
#How does the fare distribution vary across different passenger classes (Pclass)?

# %%
#lets check the fare distribution contain outlier or not with pclass

# %%
plt.figure(figsize =(8,5))
sns.boxplot(data = titanic, x='pclass', y ='fare', palette='pastel')
plt.xlabel("passenger class")
plt.ylabel("Fare")
plt.title("fare distribution accross passenger class")
# Out:
# <ipython-input-279-4d0fde463e6e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic, x='pclass', y ='fare', palette='pastel')
# Text(0.5, 1.0, 'fare distribution accross passenger class')

# %%
#as we seen the distribution contain the outliers. so lets check the outliers

# %%
titanic.groupby('pclass')['fare'].describe()
# Out:
#         count       mean        std  min      25%      50%      75%       max
# pclass
# 1       209.0  86.000578  78.905683  0.0  32.3208  61.9792  106.425  512.3292
# 2       164.0  21.889279  13.498846  0.0  13.0000  18.7500   26.000   73.5000
# 3       400.0  13.733999  10.710465  0.0   7.7750   8.0500   15.900   69.5500

# %%
Q1 = titanic.groupby('pclass')['fare'].quantile(0.25)

# %%
Q2 = titanic.groupby('pclass')['fare'].quantile(0.50)

# %%
Q3 = titanic.groupby('pclass')['fare'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound  = Q1 - 1.5 * IQR

# %%
higher_bound = Q3 + 1.5 * IQR

# %%
higher_bound
# Out:
# pclass
# 1    217.5813
# 2     45.5000
# 3     28.0875
# Name: fare, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data = titanic, x='fare', hue ='pclass', kde = True, bins = 30, palette='rocket')
plt.xlabel("Fare of passenger")
plt.ylabel("Count")
plt.title("Fare Distribution byb pclass")
# Out:
# Text(0.5, 1.0, 'Fare Distribution byb pclass')

# %% [markdown]
# #remove the fare outlier using regular one

# %%
Q1 = titanic['fare'].quantile(0.25)

# %%
Q3 = titanic['fare'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
titanic_clean = titanic[(titanic['fare']>=lower_bound) & (titanic['fare']<= upper_bound)]

# %%
titanic_clean.groupby('pclass')['fare'].describe()
# Out:
#         count       mean        std  min     25%      50%      75%      max
# pclass
# 1       112.0  39.568975  15.585120  0.0  26.550  34.8271  52.5542  71.2833
# 2       164.0  21.889279  13.498846  0.0  13.000  18.7500  26.0000  73.5000
# 3       400.0  13.733999  10.710465  0.0   7.775   8.0500  15.9000  69.5500

# %%
plt.figure(figsize =(8,5))
sns.boxplot(data = titanic_clean, x='pclass', y ='fare', palette='pastel')
plt.xlabel("passenger class")
plt.ylabel("Fare")
plt.title("fare distribution accross passenger class")
# Out:
# <ipython-input-296-3422d6c719d5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic_clean, x='pclass', y ='fare', palette='pastel')
# Text(0.5, 1.0, 'fare distribution accross passenger class')

# %%
plt.figure(figsize=(10,6))
sns.histplot(data = titanic_clean, x='fare', hue ='pclass', kde = True, bins = 30, palette='rocket')
plt.xlabel("Fare of passenger")
plt.ylabel("Count")
plt.title("Fare Distribution byb pclass")
# Out:
# Text(0.5, 1.0, 'Fare Distribution byb pclass')

# %% [markdown]
# #way 1 - remove outliers by using def funcion

# %%
def remove_outliers(df, column, groupby_col):

  def iqr_outliers_removal(sub_df):
    Q1 = sub_df[column].quantile(0.25)
    Q3 = sub_df[column].quantile(0.75)
    IQR = Q3 -Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return sub_df[(sub_df[column] >= lower_bound) & (sub_df[column] <= upper_bound)]
  return df.groupby(groupby_col, group_keys=False).apply(iqr_outliers_removal)


titanic_new_clean = remove_outliers(titanic, 'fare', 'pclass')
# Out:
# <ipython-input-298-a3462c4e7d2c>:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(groupby_col, group_keys=False).apply(iqr_outliers_removal)

# %%
plt.figure(figsize =(8,5))
sns.boxplot(data = titanic_new_clean , x='pclass', y ='fare', palette='pastel')
plt.xlabel("passenger class")
plt.ylabel("Fare")
plt.title("fare distribution accross passenger class")
# Out:
# <ipython-input-299-e050021b3d44>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic_new_clean , x='pclass', y ='fare', palette='pastel')
# Text(0.5, 1.0, 'fare distribution accross passenger class')

# %% [markdown]
# #another way to remove outliers in fare by pclass
#
# 	fare
# pclass
# 1	217.5813
#
# 2	45.5000
#
# 3	28.0875

# %%
upper_bond_dict = {1: 217.5813 , 2: 45.50, 3: 28.0875}

# %%
titanic['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
titanic_latest = titanic[
   ((titanic['pclass'] == 1) & (titanic['fare'] < upper_bond_dict[1])) |
    ((titanic['pclass'] == 2) & (titanic['fare'] < upper_bond_dict[2])) |
    ((titanic['pclass'] == 3) & (titanic['fare'] < upper_bond_dict[3]))
]

# %%
plt.figure(figsize =(8,5))
sns.boxplot(data = titanic_latest , x='pclass', y ='fare', palette='pastel')
plt.xlabel("passenger class")
plt.ylabel("Fare")
plt.title("fare distribution accross passenger class")
# Out:
# <ipython-input-303-64f5eee12d4e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic_latest , x='pclass', y ='fare', palette='pastel')
# Text(0.5, 1.0, 'fare distribution accross passenger class')

# %%
plt.figure(figsize=(10,6))
sns.histplot(data = titanic_clean, x='fare', kde = True, bins = 30, palette='rocket')
plt.xlabel("Fare of passenger")
plt.ylabel("Count")
plt.title("Fare Distribution byb pclass")
# Out:
# <ipython-input-304-6ba6c722fcb6>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data = titanic_clean, x='fare', kde = True, bins = 30, palette='rocket')
# Text(0.5, 1.0, 'Fare Distribution byb pclass')

# %%
#12. What is the relationship between age and survival rates?

# %%
titanic['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  , 25.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 30.  , 31.  , 21.5 , 34.  ,
#        15.  , 28.  ,  8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,
#         3.  ,  7.  , 49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  ,
#        17.  , 32.  , 16.  ,  0.83, 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
# 12 change this continuous feature into categorical

# %%
x = [0,10,20,30,40,50,60,70,80]

y = ['0-10', '11-20', '21-30','31-40','41-50','51-60', '61-70', '71-80']

# %%
titanic['age_group'] = pd.cut(titanic['age'], bins = x, labels = y)

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    alone age_group
# 0  False     21-30
# 1  False     31-40
# 2   True     21-30
# 3  False     31-40
# 4   True     31-40

# %%
age_survival = titanic.groupby('age_group')['survived'].mean()*100
# Out:
# <ipython-input-311-3188c01f1e72>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survival = titanic.groupby('age_group')['survived'].mean()*100

# %%
age_survival
# Out:
# age_group
# 0-10     58.730159
# 11-20    40.366972
# 21-30    37.588652
# 31-40    46.511628
# 41-50    38.095238
# 51-60    40.476190
# 61-70    25.000000
# 71-80    20.000000
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=age_survival.index, y=age_survival.values, palette='Set1' )
plt.title("Survival rate by age group")
plt.xlabel("Age group")
plt.ylabel("Survival rate in %")
# Out:
# <ipython-input-313-b3276946148e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_survival.index, y=age_survival.values, palette='Set1' )
# Text(0, 0.5, 'Survival rate in %')

# %% [markdown]
# - Childrden(0-10) had a highest survival rate ~ 58.73%
#
# - Teenages (11-20) had lower survival rate than childrens ` 40.36%
#
# -Adult (21-30)  had survival rate of ` 37%
#
# middle age (31-60) approcx survial rate is better than adult - > 40%
#
# Older adult & elderly passenger had lowest survival rate - likely struggled to reach lifeboars due to physical limitations.

# %%
# 13 What is the correlation between Fare, Pclass, and survival?

# %%
corr_matrix = titanic[['fare', 'pclass', 'survived']].corr()

# %%
corr_matrix
# Out:
#               fare    pclass  survived
# fare      1.000000 -0.554939  0.244176
# pclass   -0.554939  1.000000 -0.336633
# survived  0.244176 -0.336633  1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot= True, cmap='coolwarm')
plt.title("correlation of Fare, Pclass & Survival")
# Out:
# Text(0.5, 1.0, 'correlation of Fare, Pclass & Survival')

# %% [markdown]
# - Fare and pclass had strong negative correlation - As pclass increases Fare decreases.
#
# -Fare & survvial - weak positive correlation - passenger wgo paid higher fare had better chance to survived
#
# -Pclass - Survival - Moderate negative correlation - lower class had low survival rate, upper class  had better survival rate

# %%
#14 What are the age ranges of survivors vs. non-survivors?

# %%
plt.figure(figsize =(8,5))
sns.boxplot(data = titanic, x='survived', y ='age', palette='pastel')
plt.xlabel("Survival status ")
plt.ylabel("Age")
plt.title("Age comparison of survival vs non survival")
# Out:
# <ipython-input-319-cf83bd635c67>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic, x='survived', y ='age', palette='pastel')
# Text(0.5, 1.0, 'Age comparison of survival vs non survival')

# %%
Q1 = titanic['age'].quantile(0.25)

# %%
Q3 = titanic['age'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR

# %%
upper_bound = Q3 + 1.5 * IQR

# %%
titanic_clean1 = titanic[(titanic['age']> lower_bound)&
                         (titanic['age']<upper_bound)]

# %%
plt.figure(figsize =(8,5))
sns.boxplot(titanic_clean1['age'])
plt.xlabel("Survival status ")
plt.ylabel("Age")
plt.title("Age comparison of survival vs non survival")
# Out:
# Text(0.5, 1.0, 'Age comparison of survival vs non survival')

# %%
upper_bound
# Out:
# np.float64(63.5)

# %%
lower_bound
# Out:
# np.float64(-4.5)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data = titanic_clean1 , x = 'survived' , y = 'age' , palette = 'pastel')
plt.xlabel("survival status")
plt.ylabel("Age")
plt.title("Age comparison of survival vs non survival")
# Out:
# <ipython-input-329-93acb62b4a69>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = titanic_clean1 , x = 'survived' , y = 'age' , palette = 'pastel')
# Text(0.5, 1.0, 'Age comparison of survival vs non survival')

# %%
# 15 Are younger passangers more likely to survive compared to older passanger?

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  alone  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  False
#
#   age_group
# 0     21-30

# %%
titanic['age_group'].unique()
# Out:
# ['21-30', '31-40', '51-60', '0-10', '11-20', '61-70', '41-50', '71-80']
# Categories (8, object): ['0-10' < '11-20' < '21-30' < '31-40' < '41-50' < '51-60' < '61-70' < '71-80']

# %%
age_survival = titanic.groupby('age_group')['survived'].mean()*100
# Out:
# <ipython-input-333-3188c01f1e72>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survival = titanic.groupby('age_group')['survived'].mean()*100

# %%
age_survival
# Out:
# age_group
# 0-10     58.730159
# 11-20    40.366972
# 21-30    37.588652
# 31-40    46.511628
# 41-50    38.095238
# 51-60    40.476190
# 61-70    25.000000
# 71-80    20.000000
# Name: survived, dtype: float64

# %% [markdown]
# - younger passanger (0-10) had highest survival rate ~ 58.73%
#
# - elderly passanger (above 0) had the lowest s urvival rate ~ 25%

# %%
# 16 what is the survival rate for families(passanger with Sibsp or parch >0) vs. solo travelers?

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  alone  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  False
#
#   age_group
# 0     21-30

# %%
survial_rate_for_family = titanic.groupby('alone')['survived'].mean()*100

# %%
survial_rate_for_family
# Out:
# alone
# False    51.038576
# True     34.174312
# Name: survived, dtype: float64

# %%
survial_rate_for_family.index = ['Family Trvaler ' , 'Solo Traveler']

# %%
survial_rate_for_family
# Out:
# Family Trvaler     51.038576
# Solo Traveler      34.174312
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(6,5))
sns.barplot(x=survial_rate_for_family.index , y=survial_rate_for_family.values , palette = 'Set1')
# Out:
# <ipython-input-341-8689a00d6c3f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survial_rate_for_family.index , y=survial_rate_for_family.values , palette = 'Set1')
# <Axes: xlabel='None'>

# %% [markdown]
#  - family traveler had better chance of survival ~ 51% compared to solo traveler~ 34%

# %%
# 17 what is the distribution of family sizes among passangers , and how does it affect survival?

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  alone  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  False
#
#   age_group
# 0     21-30

# %%
titanic['family_size'] = titanic['sibsp'] + titanic['parch'] + 1

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  alone  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  False
#
#   age_group  family_size
# 0     21-30            2

# %%
titanic['family_size'].unique()
# Out:
# array([ 2,  1,  5,  3,  7,  6,  4,  8, 11])

# %%
titanic['family_size'].value_counts()
# Out:
# family_size
# 1     436
# 2     153
# 3     101
# 4      28
# 6      22
# 5      13
# 7      12
# 8       6
# 11      2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x= titanic['family_size'], palette='Set2')
# Out:
# <ipython-input-348-dedf30986acb>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= titanic['family_size'], palette='Set2')
# <Axes: xlabel='family_size', ylabel='count'>

# %%
survival_family_size = titanic.groupby('family_size')['survived'].mean()*100

# %%
survival_family_size
# Out:
# family_size
# 1     34.174312
# 2     54.901961
# 3     57.425743
# 4     71.428571
# 5     23.076923
# 6     13.636364
# 7     33.333333
# 8      0.000000
# 11     0.000000
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=survival_family_size.index , y=survival_family_size.values, palette = "viridis")
# Out:
# <ipython-input-351-08b813c13b49>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_family_size.index , y=survival_family_size.values, palette = "viridis")
# <Axes: xlabel='family_size'>

# %% [markdown]
# - single traveler hadd lower survival rate
#
# - small families (2,3,4) had highest survival rate~ 50% to 70%
#
# - large family had much lower survival rate

# %%
# 18 how does survival differ for passanger who paid exceptionallyhigh fares (Fare outliers)?

# %%
plt.figure(figsize=(8,6))
sns.boxplot(titanic['fare'])
# Out:
# <Axes: ylabel='fare'>

# %%
titanic['fare'].describe()
# Out:
# count    773.000000
# mean      35.003315
# std       52.443053
# min        0.000000
# 25%        8.050000
# 50%       16.100000
# 75%       34.375000
# max      512.329200
# Name: fare, dtype: float64

# %%
Q1 = titanic['fare'].quantile(0.25)
Q3 = titanic['fare'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
upper_bound = Q3 +1.5 * IQR

# %%
upper_bound
# Out:
# np.float64(73.8625)

# %%
titanic['high_fare'] = np.where(titanic['fare']> upper_bound , 1,0)

# %%
titanic.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 152         0       3    male  55.5      0      0   8.0500        S   Third
# 683         0       3    male  14.0      5      2  46.9000        S   Third
# 672         0       2    male  70.0      0      0  10.5000        S  Second
# 662         0       1    male  47.0      0      0  25.5875        S   First
# 805         0       3    male  31.0      0      0   7.7750        S   Third
# 94          0       3    male  59.0      0      0   7.2500        S   Third
# 492         0       1    male  55.0      0      0  30.5000        S   First
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 811         0       3    male  39.0      0      0  24.1500        S   Third
# 447         1       1    male  34.0      0      0  26.5500        S   First
#
#      alone age_group  family_size  high_fare
# 152   True     51-60            1          0
# 683  False     11-20            8          0
# 672   True     61-70            1          0
# 662   True     41-50            1          0
# 805   True     31-40            1          0
# 94    True     51-60            1          0
# 492   True     51-60            1          0
# 874  False     21-30            2          0
# 811   True     31-40            1          0
# 447   True     31-40            1          0

# %%
survival_rate = titanic.groupby('high_fare')['survived'].mean()*100

# %%
survival_rate
# Out:
# high_fare
# 0    36.538462
# 1    76.288660
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = survival_rate.index , y = survival_rate.values , palette = 'Set2')
plt.title('survival_rate - 0 - Normal VS 1 - High Fare Passanger')
plt.xlabel("passanger fare")
plt.ylabel("survival rate in % ")
# Out:
# <ipython-input-363-f2e91c6e656b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = survival_rate.index , y = survival_rate.values , palette = 'Set2')
# Text(0, 0.5, 'survival rate in % ')

# %% [markdown]
# - Normal Fare passanger survival rate is ~ 36.54%
#
# - these passangers where mostly in 2nd & 3rd class with lower priority for lifeboats
#
# - High fare passanger survival rate~76.29%
#
# - These passanger were likely in 1st class and better location and lifeboats access.

# %%
# 19- Are there any gender-based difference in survival within each class(pclass)?

# %%
gender_pclass_survival = titanic.groupby(['pclass' , 'sex'])['survived'].mean().unstack()*100

# %%
gender_pclass_survival
# Out:
# sex        female       male
# pclass
# 1       96.739130  38.461538
# 2       91.666667  18.478261
# 3       47.244094  16.117216

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = titanic , x = 'pclass' , y = 'survived' , hue = 'sex' , palette="hls")
plt.title("survival rate ny gender within each class")
plt.xlabel("passanger class (pclass)")
plt.ylabel("survival rate (%)")
# Out:
# Text(0, 0.5, 'survival rate (%)')

# %% [markdown]
# - women in 1st and 2nd class had survival rate above 90% showing string in lifeboats rather than male passanger.
#
# - 3rd class womens had also priority but less than 1st and 2nd class women . survival rate approx 47% only.and male in all classes had less priority.

# %%
# 20 - how does survival vary among passangers who embarked from differeent ports(Embarked) within the same class?

# %%
embark_pclass_survival = titanic.groupby(['pclass','embarked'])['survived'].mean().unstack()*100

# %%
embark_pclass_survival
# Out:
# embarked          C          Q          S
# pclass
# 1         70.731707  50.000000  60.000000
# 2         52.941176  66.666667  50.000000
# 3         42.592593  32.075472  21.843003

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = titanic, x = 'pclass' , y = 'survived' , hue = 'embarked' , palette = 'hls' )
plt.title("survival rate by embarked within each class")
plt.xlabel("passanger class (pclass)")
plt.ylabel("survival rate(%)")
# Out:
# Text(0, 0.5, 'survival rate(%)')

# %% [markdown]
# - 1st class passanger from cherbourg had the highest survival rate~70%
#
# - 2nd class passanger from queenstown had the highest survival rate~66%
#
# - 3rd class passanger from cherbourg had the highest were southampton had lowest survival rate~ 21%
#
# - overall passanger from cherbourg had better survival chances in most classes.

# %%
# 21 - Create a heatmap to visualize the the correlation between numeric features?

# %%
corr_matrix = titanic.corr(numeric_only = True)

# %%
corr_matrix
# Out:
#              survived    pclass       age     sibsp     parch      fare  \
# survived     1.000000 -0.336633 -0.074413 -0.041987  0.067514  0.244176
# pclass      -0.336633  1.000000 -0.397498  0.088753  0.038709 -0.554939
# age         -0.074413 -0.397498  1.000000 -0.289343 -0.189057  0.114124
# sibsp       -0.041987  0.088753 -0.289343  1.000000  0.379745  0.132237
# parch        0.067514  0.038709 -0.189057  0.379745  1.000000  0.189811
# fare         0.244176 -0.554939  0.114124  0.132237  0.189811  1.000000
# alone       -0.169709  0.110988  0.200088 -0.607515 -0.570499 -0.242704
# family_size  0.009960  0.079076 -0.292488  0.859834  0.798845  0.190746
# high_fare    0.267225 -0.554124  0.146601  0.038146  0.084026  0.756092
#
#                 alone  family_size  high_fare
# survived    -0.169709     0.009960   0.267225
# pclass       0.110988     0.079076  -0.554124
# age          0.200088    -0.292488   0.146601
# sibsp       -0.607515     0.859834   0.038146
# parch       -0.570499     0.798845   0.084026
# fare        -0.242704     0.190746   0.756092
# alone        1.000000    -0.709902  -0.194608
# family_size -0.709902     1.000000   0.071179
# high_fare   -0.194608     0.071179   1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix , annot = True , cmap = "coolwarm")
plt.title("correlation heatmap of titanic features")
# Out:
# Text(0.5, 1.0, 'correlation heatmap of titanic features')

# %%
# 22 - Use a violin plot to visualize the destribution of fare for surviovors vs non survivors

# %%
plt.figure(figsize=(8,5))
sns.violinplot(data = titanic , x = "survived" , y = "fare" , palette = "coolwarm")
plt.title("fare distribution for survival vs non survival")
plt.xticks([0,1] , ["Non-survival" , "Survival"])
plt.xlabel("Survival status")
plt.ylabel("Fare od Passanger")
# Out:
# <ipython-input-377-cd4253f0277e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = titanic , x = "survived" , y = "fare" , palette = "coolwarm")
# Text(0, 0.5, 'Fare od Passanger')

# %%
# 23 - Use a swarm plot tot analyze the relationship between pclass , sex , survival

# %%
plt.figure(figsize=(8,5))
sns.swarmplot(data = titanic , x = 'pclass' , y = 'survived' , hue = 'sex' , palette = 'rocket')
plt.title('Swarm plot of pclass , sex and survival')
plt.xlabel("passanger class")
plt.ylabel("survival")
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 70.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 62.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 84.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(62.722222222222214, 0.5, 'survival')
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 78.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 72.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 88.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# 24 - Use a box plot to analyze the fare distribution across different emebarkeation points

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'embarked' , y = 'fare' , data = titanic , palette = 'coolwarm')
plt.title("Fare Distribution Across Different Embarkation Points")
plt.xlabel("Embarkation Points")
plt.ylabel("Fare")
# Out:
# <ipython-input-381-4bbf0e9e3d81>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'embarked' , y = 'fare' , data = titanic , palette = 'coolwarm')
# Text(0, 0.5, 'Fare')

# %% [markdown]
#  Insights from the Box Plot
#
# - Cherbourg (c) passangers have the highest median fare - indicating a weather group.
#
# - Quewnstown (Q) has the smaller range of fares, with fewer extreme values compared to southampton(S).
#
# - Southampton(S) has the most spread - out fare distribution - with the widest interquartile range and several outliers.
#
# - Outliers in all categories - especially in cherbourg and southampton , suggesting some passangers paidexceptinally high fares.

# %%
# 25 - Use a pair plot to identify patterns between Age , Fare , pclass and Survived

# %%
titanic_pair = titanic[['age' , 'fare' , 'pclass' , 'survived']]

# %%
titanic_pair.head()
# Out:
#     age     fare  pclass  survived
# 0  22.0   7.2500       3         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       3         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       3         0

# %%
sns.pairplot(titanic_pair , hue = "survived")

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'alone', 'age_group', 'family_size', 'high_fare'],
#       dtype='object')

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# alone          0
# age_group      0
# family_size    0
# high_fare      0
# dtype: int64

# %%
# 29 -Can the dataset be stratified into groups (e.g., age, class, gender) with distinctly high or low
#survival probabilities?

# %%
group_survival = titanic.groupby(['age_group' , 'pclass' , 'sex'])['survived'].mean().reset_index()
# Out:
# <ipython-input-389-aa1d42b2b5ad>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_survival = titanic.groupby(['age_group' , 'pclass' , 'sex'])['survived'].mean().reset_index()

# %%
group_survival.head(5)
# Out:
#   age_group  pclass     sex  survived
# 0      0-10       1  female   0.00000
# 1      0-10       1    male   1.00000
# 2      0-10       2  female   1.00000
# 3      0-10       2    male   1.00000
# 4      0-10       3  female   0.47619

# %%
group_survival['survived'] = group_survival['survived']*100

# %%
group_survival.head(5)
# Out:
#   age_group  pclass     sex    survived
# 0      0-10       1  female    0.000000
# 1      0-10       1    male  100.000000
# 2      0-10       2  female  100.000000
# 3      0-10       2    male  100.000000
# 4      0-10       3  female   47.619048

# %%
plt.figure(figsize=(12,6))
sns.barplot(data =group_survival, x='age_group', y='survived' , hue='pclass', palette='Set1')
plt.title("Survival probability across age_group, pclass, and gender")
plt.xlabel("Age_group")
plt.ylabel("survival rate (%)")
# Out:
# Text(0, 0.5, 'survival rate (%)')

# %%
# 30 - #What trends emerge when visualizing survival rates by age, grouped by gender and
#passenger class?

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data =group_survival, x='age_group', y='survived' , hue='sex',style='pclass', palette='Set1')
plt.title("Survival probability across age_group, pclass, and gender")
plt.xlabel("Age_group")
plt.ylabel("survival rate (%)")
# Out:
# Text(0, 0.5, 'survival rate (%)')

# %% [markdown]
# - female in 1st class and 2nd class had the highest survival rates.
#
# -womens middle age 41-50 with pclass 3 had lowest survival rate.
#
# - as well as paclass 1 and class 2 male passenger for age group - 51-70 had lowest survival rate.
#
# - male passenger of pclass 3 with age group from 50 to 80 had least lowest survival rate
#
# - especially boys and girls childrens had high survival rate
